# %% [markdown]
# # importing labraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
# Load the dataset into a Pandas DataFrame
sales_pipline = pd.read_csv('sales-pipeline.csv')
sales_pipline
# Out:
#                  Account Opportunity_ID         Sales_Agent   Deal_Stage  \
# 0             Sunnamplex       67HY0MW7       Donn Cantrell          Won
# 1                    NaN       MA82HVCI      James Ascencio  In_Progress
# 2                    NaN       BRL1KVVH      Vicki Laflamme         Lost
# 3                  Silis       R22O68FF     Niesha Huffines          Won
# 4                  Silis       J78AK31N       Kami Bicknell          Won
# ...                  ...            ...                 ...          ...
# 14272           Kan-code       HI8K524C     Darcel Schlecht          Won
# 14273            Initech       4CS92BTC     Darcel Schlecht          Won
# 14274            Domzoom       VWNFKJPJ  Jonathan Berthelot          Won
# 14275         Stanredtax       4FI7GRQG   Versie Hillebrand          Won
# 14276  Cyberdyne Systems       RG633VHW      Cecily Lampkin          Won
#
#             Product  Close_Date  Close_Value  Created_On
# ...

# %% [markdown]
# # 1st dataset anyalisis and data visuvalization

# %%
# Check the dimensions of the dataset
print(sales_pipline.shape)

# Check the data types of the columns
print(sales_pipline.dtypes)

# Check for missing values
print(sales_pipline.isnull().sum())

# Check for duplicates
print(sales_pipline.duplicated().sum())
# Out:
# (14277, 8)
# Account            object
# Opportunity_ID     object
# Sales_Agent        object
# Deal_Stage         object
# Product            object
# Close_Date         object
# Close_Value       float64
# Created_On         object
# dtype: object
# Account           5393
# Opportunity_ID       0
# Sales_Agent          0
# Deal_Stage           0
# Product              0
# Close_Date        4346
# Close_Value       4365
# Created_On           0
# dtype: int64
# 0

# %%
# Sales Agent distribution
plt.figure(figsize=(12, 8))
sns.countplot(y='Sales_Agent', data=df, order=df['Sales_Agent'].value_counts().index)
plt.title('Distribution of Sales Agents')
plt.xlabel('Count')
plt.ylabel('Sales Agent')
plt.tight_layout()
plt.show()

# %%
# Manager distribution
plt.figure(figsize=(12, 8))
sns.countplot(y='Manager', data=df, order=df['Manager'].value_counts().index)
plt.title('Distribution of Managers')
plt.xlabel('Count')
plt.ylabel('Manager')
plt.tight_layout()
plt.show()

# %%
# Regional Office distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Regional_Office', data=df, order=df['Regional_Office'].value_counts().index)
plt.title('Distribution of Regional Offices')
plt.xlabel('Regional Office')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('sales-teams.csv', encoding='ascii')

# Visualize categorical data

# Sales Agent distribution
plt.figure(figsize=(12, 8))
sns.countplot(y='Sales_Agent', data=df, order=df['Sales_Agent'].value_counts().index)
plt.title('Distribution of Sales Agents')
plt.xlabel('Count')
plt.ylabel('Sales Agent')
plt.tight_layout()
plt.show()

# Manager distribution
plt.figure(figsize=(12, 8))
sns.countplot(y='Manager', data=df, order=df['Manager'].value_counts().index)
plt.title('Distribution of Managers')
plt.xlabel('Count')
plt.ylabel('Manager')
plt.tight_layout()
plt.show()

# Regional Office distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Regional_Office', data=df, order=df['Regional_Office'].value_counts().index)
plt.title('Distribution of Regional Offices')
plt.xlabel('Regional Office')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# From the summary, we observe that:
#
# The dataset contains sales pipeline information with columns like Account, Opportunity_ID, Sales_Agent, Deal_Stage, Product, Close_Date, Close_Value, and Created_On.
# There are missing values in the 'Account', 'Close_Date', and 'Close_Value' columns, indicating some opportunities are still in progress or lost without a closing value.
# The 'Close_Value' column has a wide range, with a mean of approximately 1809.62 and a maximum value of 43593, suggesting variability in the deal sizes.
# The 'Deal_Stage' column shows that a significant portion of the deals have been won.
# This initial analysis provides a foundation for deeper investigation into the sales pipeline's performance, deal sizes, and the effectiveness of sales agents.

# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the data
sales_data = pd.read_csv('sales-pipeline.csv', encoding='ascii')

# Visualization 1: Deal Stage Distribution
plt.figure(figsize=(10, 6))
sns.countplot(y='Deal_Stage', data=sales_data, order = sales_data['Deal_Stage'].value_counts().index)
plt.title('Deal Stage Distribution')
plt.xlabel('Count')
plt.ylabel('Deal Stage')
plt.show()

# Visualization 2: Top 10 Sales Agents by Number of Deals
plt.figure(figsize=(10, 6))
top_agents = sales_data['Sales_Agent'].value_counts().head(10)
sns.barplot(x=top_agents.values, y=top_agents.index)
plt.title('Top 10 Sales Agents by Number of Deals')
plt.xlabel('Number of Deals')
plt.ylabel('Sales Agent')
plt.show()

print('Visualizations generated.')
# Out:
# Visualizations generated.

# %% [markdown]
# These visualizations provide insights into the distribution of deal stages across the sales pipeline and highlight the top-performing sales agents based on the number of deals they have managed.

# %% [markdown]
# # Loading the 2nd dataset

# %%
import pandas as pd

# Load the data
accounts_data = pd.read_csv('accounts.csv', encoding='ascii')

# Display the first few rows of the dataframe
display(accounts_data.head())

# Display summary statistics
display(accounts_data.describe(include='all'))

# Check for missing values
display(accounts_data.isnull().sum())

print('EDA on accounts.csv completed.')
# Out:
#             Account  Revenue  Employees
# 0        Sunnamplex  4592.96    13938.0
# 1             Silis  5339.57    18053.0
# 2      Groovestreet  2728.86     6486.0
# 3           Donware  2009.52     3409.0
# 4  Wonka Industries  4962.27     4687.0
#            Account      Revenue     Employees
# count           97    97.000000     97.000000
# unique          97          NaN           NaN
# top     Sunnamplex          NaN           NaN
# freq             1          NaN           NaN
# mean           NaN  1663.317629   4183.113402
# std            NaN  1470.744287   4404.266830
# min            NaN    14.790000     26.000000
# 25%            NaN   431.100000    854.000000
# 50%            NaN  1244.710000   2695.000000
# 75%            NaN  2356.070000   6364.000000
# max            NaN  6085.600000  20587.000000
# Account      0
# Revenue      0
# Employees    0
# dtype: int64
# EDA on accounts.csv completed.

# %%
import pandas as pd

# Load the accounts data
df = pd.read_csv('accounts.csv')

# Display basic information and the first few rows of the dataframe
df_info = df.info()
df_head = df.head()

print(df_info)
print(df_head)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Account    97 non-null     object
#  1   Revenue    97 non-null     float64
#  2   Employees  97 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 2.4+ KB
# None
#             Account  Revenue  Employees
# 0        Sunnamplex  4592.96    13938.0
# 1             Silis  5339.57    18053.0
# 2      Groovestreet  2728.86     6486.0
# 3           Donware  2009.52     3409.0
# 4  Wonka Industries  4962.27     4687.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize the distribution of revenue
plt.figure(figsize=(10, 6))
sns.histplot(df['Revenue'], bins=20, kde=True)
plt.title('Distribution of Revenue Across Accounts')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Visualize the relationship between number of employees and revenue
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Employees', y='Revenue', data=df)
plt.title('Relationship Between Number of Employees and Revenue')
plt.xlabel('Number of Employees')
plt.ylabel('Revenue')
plt.tight_layout()
plt.show()

# Identify top accounts by revenue
top_accounts = df.sort_values(by='Revenue', ascending=False).head(10)
print(top_accounts)
# Out:
#              Account  Revenue  Employees
# 75    Dalttechnology  6085.60    20587.0
# 1              Silis  5339.57    18053.0
# 45             Newex  5093.78    10086.0
# 4   Wonka Industries  4962.27     4687.0
# 5           Faxquote  4939.54    17075.0
# 0         Sunnamplex  4592.96    13938.0
# 70             Isdom  4514.68    12424.0
# 35           Golddex  4340.32    11891.0
# 66           Conecom  4242.85    14589.0
# 51  Stark Industries  4221.65    13886.0

# %% [markdown]
# From the summary, we observe that:
#
# The dataset contains information on accounts with columns like Account, Revenue, and Employees.
# There are no missing values in the dataset, indicating complete data for all accounts.
# The 'Revenue' and 'Employees' columns show a wide range of values, with means of approximately 1663.32 and 4183.11 respectively, suggesting variability in the size and financial performance of the accounts.
# This initial analysis provides a foundation for deeper investigation into the accounts' financial performance and workforce size.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the data
accounts_data = pd.read_csv('accounts.csv', encoding='ascii')

# Visualization 1: Revenue Distribution
plt.figure(figsize=(10, 6))
sns.histplot(accounts_data['Revenue'], bins=20, kde=True)
plt.title('Revenue Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.show()

# Visualization 2: Employees Distribution
plt.figure(figsize=(10, 6))
sns.histplot(accounts_data['Employees'], bins=20, kde=True)
plt.title('Employees Distribution')
plt.xlabel('Number of Employees')
plt.ylabel('Frequency')
plt.show()

print('Visualizations generated.')
# Out:
# Visualizations generated.

# %% [markdown]
# These visualizations provide insights into the distribution of revenue and the number of employees across the accounts. The Revenue Distribution chart shows the spread of revenue among the accounts, while the Employees Distribution chart illustrates how the number of employees varies across different accounts.

# %% [markdown]
# # 3rd dataset load

# %%
import pandas as pd

# Load the data
sales_teams_data = pd.read_csv('sales-teams.csv', encoding='ascii')

# Display the first few rows of the dataframe
display(sales_teams_data.head())

# Display summary statistics
display(sales_teams_data.describe(include='all'))

# Check for missing values
display(sales_teams_data.isnull().sum())

print('EDA on sales-teams.csv completed.')
# Out:
#        Sales_Agent        Manager Regional_Office
# 0    Donn Cantrell  Rocco Neubert         Central
# 1   James Ascencio  Summer Sewald            West
# 2   Vicki Laflamme   Celia Rouche            West
# 3  Niesha Huffines  Melvin Marxen            East
# 4    Kami Bicknell  Summer Sewald            West
#           Sales_Agent        Manager Regional_Office
# count              30             30              30
# unique             30              6               3
# top     Donn Cantrell  Rocco Neubert         Central
# freq                1              5              10
# Sales_Agent        0
# Manager            0
# Regional_Office    0
# dtype: int64
# EDA on sales-teams.csv completed.

# %% [markdown]
# From the summary, we observe that:
#
# The dataset contains information on sales agents, their managers, and regional offices.
# There are 30 unique sales agents, each managed by one of 6 managers and located in one of 3 regional offices.
# There are no missing values in the dataset, indicating complete data for all sales team members.
# This initial analysis provides a foundation for deeper investigation into the structure and distribution of the sales teams across different regions.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the data
sales_teams_data = pd.read_csv('sales-teams.csv', encoding='ascii')

# Visualization 1: Number of Sales Agents per Manager
plt.figure(figsize=(10, 6))
sns.countplot(y='Manager', data=sales_teams_data, order = sales_teams_data['Manager'].value_counts().index)
plt.title('Number of Sales Agents per Manager')
plt.xlabel('Number of Sales Agents')
plt.ylabel('Manager')
plt.show()

# Visualization 2: Number of Sales Agents per Regional Office
plt.figure(figsize=(10, 6))
sns.countplot(x='Regional_Office', data=sales_teams_data, order = sales_teams_data['Regional_Office'].value_counts().index)
plt.title('Number of Sales Agents per Regional Office')
plt.xlabel('Regional Office')
plt.ylabel('Number of Sales Agents')
plt.show()

print('Visualizations generated.')
# Out:
# Visualizations generated.

# %% [markdown]
# These visualizations provide insights into the distribution of sales agents across different managers and regional offices. The first chart shows how sales agents are distributed among the managers, indicating the management structure. The second chart illustrates the number of sales agents working in each regional office, highlighting the geographical distribution of the sales team.

# %% [markdown]
# # 4th dataset load

# %%
import pandas as pd

# Load the data
products_data = pd.read_csv('products.csv', encoding='ascii')

# Display the first few rows of the dataframe
display(products_data.head())

# Display summary statistics
display(products_data.describe(include='all'))

# Check for missing values
display(products_data.isnull().sum())

print('EDA on products.csv completed.')
# Out:
#         Product  Sales_Price
# 0   GTXAdvanced        649.0
# 1      GTXBasic        641.0
# 2        MGRPFU       3959.0
# 3        MGRPFS         64.0
# 4  GTXPlusBasic       1279.0
#             Product   Sales_Price
# count             8      8.000000
# unique            8           NaN
# top     GTXAdvanced           NaN
# freq              1           NaN
# mean            NaN   6230.000000
# std             NaN  10388.306214
# min             NaN     64.000000
# 25%             NaN    647.000000
# 50%             NaN   2619.000000
# 75%             NaN   5816.750000
# max             NaN  31229.000000
# Product        0
# Sales_Price    0
# dtype: int64
# EDA on products.csv completed.

# %% [markdown]
# The EDA on products.csv reveals:
#
# The dataset contains information on products with their sales price.
# There are 8 unique products listed in the dataset.
# The Sales_Price column shows a wide range of values, with a mean of approximately 6230, indicating variability in the pricing of different products.
# There are no missing values in the dataset, indicating complete data for all products listed.
# This analysis provides a foundation for deeper investigation into the product offerings and their pricing strategies.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the data
products_data = pd.read_csv('products.csv', encoding='ascii')

# Visualization: Sales Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(products_data['Sales_Price'], bins=10, kde=True)
plt.title('Sales Price Distribution')
plt.xlabel('Sales Price')
plt.ylabel('Frequency')
plt.show()

print('Visualization generated.')
# Out:
# Visualization generated.

# %% [markdown]
# This visualization shows the distribution of sales prices for the products. The histogram, complemented by a kernel density estimate (KDE), provides a visual representation of the range and frequency of sales prices across different products.

# %% [markdown]
# # 5th dataset load

# %%
import pandas as pd

# Load the data
clicks_data = pd.read_csv('clicks.csv', encoding='ascii')

# Display the first few rows of the dataframe
display(clicks_data.head())

# Display summary statistics
display(clicks_data.describe(include='all'))

# Check for missing values
display(clicks_data.isnull().sum())

print('EDA on clicks.csv completed.')
# Out:
#    Created_On    Source     Industry
# 0  2016-11-14  Referral           IT
# 1  2016-11-14    Social           IT
# 2  2016-11-14      Paid         SaaS
# 3  2016-11-14    Direct         SaaS
# 4  2016-11-15   Organic  Health Care
#         Created_On Source Industry
# count        30244  30244    30244
# unique         396      6        7
# top     2017-07-24   Paid  Telecom
# freq           267   6520     6573
# Created_On    0
# Source        0
# Industry      0
# dtype: int64
# EDA on clicks.csv completed.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'Created_On' to datetime
df['Created_On'] = pd.to_datetime(df['Created_On'])

# Visualize clicks over time
plt.figure(figsize=(12, 6))
df['Created_On'].value_counts().sort_index().plot(kind='line')
plt.title('Clicks Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Clicks')
plt.tight_layout()
plt.show()

# Visualize clicks by source
plt.figure(figsize=(10, 6))
sns.countplot(y='Source', data=df, order=df['Source'].value_counts().index)
plt.title('Clicks by Source')
plt.xlabel('Count')
plt.ylabel('Source')
plt.tight_layout()
plt.show()

# Visualize clicks by industry
plt.figure(figsize=(10, 6))
sns.countplot(y='Industry', data=df, order=df['Industry'].value_counts().index)
plt.title('Clicks by Industry')
plt.xlabel('Count')
plt.ylabel('Industry')
plt.tight_layout()
plt.show()

# %% [markdown]
# The EDA on clicks.csv reveals:
#
# The dataset contains information on clicks with columns for creation date (Created_On), source (Source), and industry (Industry).
# There are 30,244 entries with 396 unique creation dates, 6 unique sources, and 7 unique industries.
# The most frequent source of clicks is Paid, and the most represented industry is Telecom.
# There are no missing values in the dataset, indicating complete data for all entries.
# This analysis provides a foundation for deeper investigation into the clicks' patterns, sources, and industry distribution.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the data
clicks_data = pd.read_csv('clicks.csv', encoding='ascii')

# Visualization 1: Clicks by Source
plt.figure(figsize=(10, 6))
sns.countplot(x='Source', data=clicks_data, order = clicks_data['Source'].value_counts().index)
plt.title('Clicks by Source')
plt.xlabel('Source')
plt.ylabel('Number of Clicks')
plt.xticks(rotation=45)
plt.show()

# Visualization 2: Clicks by Industry
plt.figure(figsize=(10, 6))
sns.countplot(x='Industry', data=clicks_data, order = clicks_data['Industry'].value_counts().index)
plt.title('Clicks by Industry')
plt.xlabel('Industry')
plt.ylabel('Number of Clicks')
plt.xticks(rotation=45)
plt.show()

print('Visualizations generated.')
# Out:
# Visualizations generated.

# %% [markdown]
# These visualizations provide insights into the distribution of clicks by source and industry. The first chart shows the number of clicks generated from each source, highlighting which sources are driving the most traffic. The second chart illustrates the distribution of clicks across different industries, indicating which industries are more actively engaging with the content or ads.

# %% [markdown]
# # combined data analysis

# %%
import pandas as pd

# Load all datasets
sales_pipeline = pd.read_csv('sales-pipeline.csv')
accounts = pd.read_csv('accounts.csv')
sales_teams = pd.read_csv('sales-teams.csv')
products = pd.read_csv('products.csv')
clicks = pd.read_csv('clicks.csv')

# Merge datasets for a comprehensive analysis
# Merging sales_pipeline with accounts on Account_Name and Account
merged_df = pd.merge(sales_pipeline, accounts, left_on='Account', right_on='Account', how='left')

# Merging the above with sales_teams on Sales_Agent
merged_df = pd.merge(merged_df, sales_teams, on='Sales_Agent', how='left')

# Merging the above with products on Product
merged_df = pd.merge(merged_df, products, on='Product', how='left')

# For clicks, we need a common key for a meaningful merge, which might not be directly available

# Display the head of the merged dataframe to ensure correctness
print(merged_df.head())

# Check for missing values in the merged dataframe
display(merged_df.isnull().sum())

print('Merging of datasets completed.')
# Out:
#       Account Opportunity_ID      Sales_Agent   Deal_Stage   Product  \
# 0  Sunnamplex       67HY0MW7    Donn Cantrell          Won  GTXBasic
# 1         NaN       MA82HVCI   James Ascencio  In_Progress    GTXPro
# 2         NaN       BRL1KVVH   Vicki Laflamme         Lost  GTXBasic
# 3       Silis       R22O68FF  Niesha Huffines          Won  GTXBasic
# 4       Silis       J78AK31N    Kami Bicknell          Won    MGRPFU
#
#    Close_Date  Close_Value  Created_On  Revenue  Employees        Manager  \
# 0  2017-05-06        500.0  2017-04-24  4592.96    13938.0  Rocco Neubert
# 1         NaN          NaN  2017-06-15      NaN        NaN  Summer Sewald
# 2  2017-08-03          0.0  2017-05-19      NaN        NaN   Celia Rouche
# 3  2017-06-27        524.0  2017-03-21  5339.57    18053.0  Melvin Marxen
# 4  2017-08-04       4794.0  2017-05-15  5339.57    18053.0  Summer Sewald
#
#   Regional_Office  Sales_Price
# 0         Central        641.0
# 1            West       5624.0
# ...

# %%
# First, let's check the columns of each dataframe to identify the correct keys for merging
print('Sales Pipeline Columns:', sales_pipeline.columns.tolist())
print('Accounts Columns:', accounts.columns.tolist())
print('Sales Teams Columns:', sales_teams.columns.tolist())
print('Products Columns:', products.columns.tolist())
print('Clicks Columns:', clicks.columns.tolist())
# Out:
# Sales Pipeline Columns: ['Account', 'Opportunity_ID', 'Sales_Agent', 'Deal_Stage', 'Product', 'Close_Date', 'Close_Value', 'Created_On']
# Accounts Columns: ['Account', 'Revenue', 'Employees']
# Sales Teams Columns: ['Sales_Agent', 'Manager', 'Regional_Office']
# Products Columns: ['Product', 'Sales_Price']
# Clicks Columns: ['Created_On', 'Source', 'Industry']

# %% [markdown]
# This merged dataframe now includes information from the sales pipeline, accounts, sales teams, and products datasets. It provides a comprehensive view of each sales opportunity, including the account details, sales agent information, deal stage, product details, and associated sales price.
#
# However, there are missing values in several columns, notably in 'Account', 'Revenue', 'Employees', 'Close_Date', and 'Close_Value'. These missing values will need to be addressed during the data analysis process.
#
# Next steps could involve analyzing sales performance, product popularity, sales team effectiveness, and account characteristics. Additionally, we can explore trends over time and identify patterns related to successful deals.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load datasets
sales_pipeline = pd.read_csv('sales-pipeline.csv')
accounts = pd.read_csv('accounts.csv')
sales_teams = pd.read_csv('sales-teams.csv')
products = pd.read_csv('products.csv')
clicks = pd.read_csv('clicks.csv')

# Visualization 1: Sales Pipeline Deal Stages
plt.figure(figsize=(10, 6))
sns.countplot(x='Deal_Stage', data=sales_pipeline, palette='Set2')
plt.title('Sales Pipeline Deal Stages')
plt.xlabel('Deal Stage')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('sales_pipeline_deal_stages.png')
plt.show()

# Visualization 2: Accounts Revenue Distribution
plt.figure(figsize=(10, 6))
sns.histplot(accounts['Revenue'], bins=30, kde=True, color='skyblue')
plt.title('Accounts Revenue Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.tight_layout()
plt.savefig('accounts_revenue_distribution.png')
plt.show()

# Visualization 3: Sales Teams Regional Office Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Regional_Office', data=sales_teams, palette='Set3')
plt.title('Sales Teams Regional Office Distribution')
plt.xlabel('Regional Office')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('sales_teams_regional_office_distribution.png')
plt.show()

# Visualization 4: Products Sales Price Distribution
plt.figure(figsize=(10, 6))
sns.histplot(products['Sales_Price'], bins=20, kde=True, color='purple')
plt.title('Products Sales Price Distribution')
plt.xlabel('Sales Price')
plt.ylabel('Frequency')
plt.tight_layout()
plt.savefig('products_sales_price_distribution.png')
plt.show()

# Visualization 5: Clicks Source Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Source', data=clicks, palette='Set1')
plt.title('Clicks Source Distribution')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('clicks_source_distribution.png')
plt.show()

print('Visualizations generated and saved.')
# Out:
# Visualizations generated and saved.

# %% [markdown]
# These visualizations provide insights into various aspects of the data, including the distribution of deal stages in the sales pipeline, revenue distribution among accounts, the distribution of sales teams across regional offices, sales price distribution for products, and the distribution of clicks by source. Each visualization helps in understanding different facets of the business operations and customer interactions.

# %%
import pandas as pd

# Load the sales-pipeline data
df = pd.read_csv('sales-pipeline.csv')

# Display basic information and the first few rows of the dataframe
df_info = df.info()
df_head = df.head()

print(df_info)
print(df_head)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14277 entries, 0 to 14276
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account         8884 non-null   object
#  1   Opportunity_ID  14277 non-null  object
#  2   Sales_Agent     14277 non-null  object
#  3   Deal_Stage      14277 non-null  object
#  4   Product         14277 non-null  object
#  5   Close_Date      9931 non-null   object
#  6   Close_Value     9912 non-null   float64
#  7   Created_On      14277 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 892.4+ KB
# None
#       Account Opportunity_ID      Sales_Agent   Deal_Stage   Product  \
# 0  Sunnamplex       67HY0MW7    Donn Cantrell          Won  GTXBasic
# 1         NaN       MA82HVCI   James Ascencio  In_Progress    GTXPro
# 2         NaN       BRL1KVVH   Vicki Laflamme         Lost  GTXBasic
# 3       Silis       R22O68FF  Niesha Huffines          Won  GTXBasic
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert 'Close_Date' and 'Created_On' to datetime
df['Close_Date'] = pd.to_datetime(df['Close_Date'])
df['Created_On'] = pd.to_datetime(df['Created_On'])

# Visualize the distribution of deals across different stages
plt.figure(figsize=(10, 6))
sns.countplot(y='Deal_Stage', data=df, order=df['Deal_Stage'].value_counts().index)
plt.title('Distribution of Deals Across Different Stages')
plt.xlabel('Count')
plt.ylabel('Deal Stage')
plt.tight_layout()
plt.show()

# Visualize the performance of sales agents
plt.figure(figsize=(12, 8))
sns.countplot(y='Sales_Agent', data=df[df['Deal_Stage'] == 'Won'], order=df[df['Deal_Stage'] == 'Won']['Sales_Agent'].value_counts().index)
plt.title('Performance of Sales Agents (Closed Deals)')
plt.xlabel('Number of Closed Deals')
plt.ylabel('Sales Agent')
plt.tight_layout()
plt.show()

# Visualize trends in close value over time
plt.figure(figsize=(12, 6))
df[df['Deal_Stage'] == 'Won'].groupby(df['Close_Date'].dt.to_period('M'))['Close_Value'].sum().plot(kind='line')
plt.title('Trends in Close Value Over Time')
plt.xlabel('Close Date')
plt.ylabel('Total Close Value')
plt.tight_layout()
plt.show()
